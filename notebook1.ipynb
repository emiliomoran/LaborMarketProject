# %% [markdown]
# # Manipulacion del dataset original

# %%
import pandas as pd

# %%
data = pd.read_csv('latim.csv')

# %% [markdown]
# ## Exploración del dataset

# %%
data.head()
# Out:
#   region region_acro_BID region_2 pais_extendido extended_country  \
# 0    ALC             CSC      CSC      Argentina        Argentina
# 1    ALC             CSC      CSC      Argentina        Argentina
# 2    ALC             CSC      CSC      Argentina        Argentina
# 3    ALC             CSC      CSC      Argentina        Argentina
# 4    ALC             CSC      CSC      Argentina        Argentina
#
#   pais_acronimo  anio  anio2 ronda  \
# 0           ARG  1992   1992   m10
# 1           ARG  1992   1992   m10
# 2           ARG  1992   1992   m10
# 3           ARG  1992   1992   m10
# 4           ARG  1992   1992   m10
#
#                                      var_descripcion  ...     firm_size  \
# 0  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# 1  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# 2  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7445025 entries, 0 to 7445024
# Data columns (total 37 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   region                          object
#  1   region_acro_BID                 object
#  2   region_2                        object
#  3   pais_extendido                  object
#  4   extended_country                object
#  5   pais_acronimo                   object
#  6   anio                            int64
#  7   anio2                           int64
#  8   ronda                           object
#  9   var_descripcion                 object
#  10  var_description                 object
#  11  tipo_variable                   object
#  12  var_type                        object
#  13  var_categoria                   object
#  14  var_category                    object
#  15  var_subcategoria                object
#  16  var_subcategory                 object
# ...

# %%
data.var_type.unique()
# Out:
# array(['levels, #', 'rate, %'], dtype=object)

# %%
data.var_category.unique()
# Out:
# array(['Employment', 'Population', 'Unemployment',
#        'Poverty and vulnerability', 'Empleo', 'Social security', 'Income'],
#       dtype=object)

# %% [markdown]
# ## Conversión de datos a un formato usable

# %%
data['valor'] = data['valor'].str.replace(',','')
data['valor'] = data['valor'].astype('float')

# %%
data.head()
# Out:
#   region region_acro_BID region_2 pais_extendido extended_country  \
# 0    ALC             CSC      CSC      Argentina        Argentina
# 1    ALC             CSC      CSC      Argentina        Argentina
# 2    ALC             CSC      CSC      Argentina        Argentina
# 3    ALC             CSC      CSC      Argentina        Argentina
# 4    ALC             CSC      CSC      Argentina        Argentina
#
#   pais_acronimo  anio  anio2 ronda  \
# 0           ARG  1992   1992   m10
# 1           ARG  1992   1992   m10
# 2           ARG  1992   1992   m10
# 3           ARG  1992   1992   m10
# 4           ARG  1992   1992   m10
#
#                                      var_descripcion  ...     firm_size  \
# 0  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# 1  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# 2  Trabajadores en ocupaciones administrativas y ...  ...  Do not apply
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7445025 entries, 0 to 7445024
# Data columns (total 37 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   region                          object
#  1   region_acro_BID                 object
#  2   region_2                        object
#  3   pais_extendido                  object
#  4   extended_country                object
#  5   pais_acronimo                   object
#  6   anio                            int64
#  7   anio2                           int64
#  8   ronda                           object
#  9   var_descripcion                 object
#  10  var_description                 object
#  11  tipo_variable                   object
#  12  var_type                        object
#  13  var_categoria                   object
#  14  var_category                    object
#  15  var_subcategoria                object
#  16  var_subcategory                 object
# ...

# %%
data[data['var_type'] == 'levels, #']
# Out:
#         region region_acro_BID region_2 pais_extendido extended_country  \
# 0          ALC             CSC      CSC      Argentina        Argentina
# 1          ALC             CSC      CSC      Argentina        Argentina
# 2          ALC             CSC      CSC      Argentina        Argentina
# 3          ALC             CSC      CSC      Argentina        Argentina
# 4          ALC             CSC      CSC      Argentina        Argentina
# ...        ...             ...      ...            ...              ...
# 7445020    ALC             CSC      CSC        Uruguay          Uruguay
# 7445021    ALC             CSC      CSC        Uruguay          Uruguay
# 7445022    ALC             CSC      CSC        Uruguay          Uruguay
# 7445023    ALC             CSC      CSC        Uruguay          Uruguay
# 7445024    ALC             CSC      CSC        Uruguay          Uruguay
#
#         pais_acronimo  anio  anio2 ronda  \
# 0                 ARG  1992   1992   m10
# ...

# %%
data[data['var_type'] == 'rate, %']
# Out:
#         region region_acro_BID region_2 pais_extendido extended_country  \
# 88         ALC             CSC      CSC      Argentina        Argentina
# 89         ALC             CSC      CSC      Argentina        Argentina
# 90         ALC             CSC      CSC      Argentina        Argentina
# 91         ALC             CSC      CSC      Argentina        Argentina
# 92         ALC             CSC      CSC      Argentina        Argentina
# ...        ...             ...      ...            ...              ...
# 7444064    ALC             CSC      CSC        Uruguay          Uruguay
# 7444065    ALC             CSC      CSC        Uruguay          Uruguay
# 7444066    ALC             CSC      CSC        Uruguay          Uruguay
# 7444067    ALC             CSC      CSC        Uruguay          Uruguay
# 7444068    ALC             CSC      CSC        Uruguay          Uruguay
#
#         pais_acronimo  anio  anio2 ronda  \
# 88                ARG  1992   1992   m10
# ...

# %% [markdown]
# ## Eliminación de columnas repetidas

# %%
dataUniqueCols = data.drop(columns=['region_acro_BID','region_2','pais_extendido','anio2','var_descripcion','tipo_variable','var_categoria','var_subcategoria','rango_edad','genero','zona_geografica','nivel_educativo','tam_de_firma','quintil_ingreso_laboral','quintil_ingreso_total','fuente_datos_original','institucion_ejecutora','institucion_ejecutora_acronimo'])

# %%
dataUniqueCols.head()
# Out:
#   region extended_country pais_acronimo  anio ronda  \
# 0    ALC        Argentina           ARG  1992   m10
# 1    ALC        Argentina           ARG  1992   m10
# 2    ALC        Argentina           ARG  1992   m10
# 3    ALC        Argentina           ARG  1992   m10
# 4    ALC        Argentina           ARG  1992   m10
#
#                                      var_description   var_type var_category  \
# 0  Employed workers in administrative occupations...  levels, #   Employment
# 1  Employed workers in administrative occupations...  levels, #   Employment
# 2  Employed workers in administrative occupations...  levels, #   Employment
# 3  Employed workers in administrative occupations...  levels, #   Employment
# 4  Employed workers in administrative occupations...  levels, #   Employment
#
#       var_subcategory    cobertura_geografica               age_range gender  \
# 0  Occupational group  15 Aglomerados urbanos      15 to 24 years old  Total
# ...

# %%
dataUniqueCols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7445025 entries, 0 to 7445024
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   region                 object
#  1   extended_country       object
#  2   pais_acronimo          object
#  3   anio                   int64
#  4   ronda                  object
#  5   var_description        object
#  6   var_type               object
#  7   var_category           object
#  8   var_subcategory        object
#  9   cobertura_geografica   object
#  10  age_range              object
#  11  gender                 object
#  12  geographical_zone      object
#  13  educational_level      object
#  14  firm_size              object
#  15  labor_income_quintile  object
#  16  total_income_quintile  object
#  17  non_average            int64
#  18  valor                  float64
# dtypes: float64(1), int64(2), object(16)
# memory usage: 1.1+ GB

# %% [markdown]
# ## Guardar el nuevo dataframe en un archivo

# %%
dataUniqueCols.to_csv('latimUniqueCols.csv', index=False)
