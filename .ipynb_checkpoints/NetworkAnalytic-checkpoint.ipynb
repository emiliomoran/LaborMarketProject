# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('analystFinal2.csv')

# %%
df.head()
# Out:
#    id                     Nombre de trabajo              Compania  \
# 0   0  Se necesita personal de 17 a 35 años  EMPLEOS EN GUAYAQUIL
# 1   1                    Auxiliar de bodega             PARTESCAT
# 2   2                      Chofer y oficial        Pluproxsa S.A.
# 3   3                 Mecánico Motocicletas      MULTIMOTOS S. A.
# 4   4                              Mecánico          CONFIDENCIAL
#
#                      Salario                                  Categoria  \
# 0         $ 500,00 (Mensual)  Almacenamiento / Logística / Distribución
# 1  500,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 2  406,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 3  394,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 4                 A convenir  Almacenamiento / Logística / Distribución
#
#                    Subcategoria   Localidad              Activo desde  \
# 0         Oficios y Profesiones   Guayaquil  16/08/2020 - 14:32:54 pm
# 1      Logística y Distribución       Quito  16/08/2020 - 12:46:40 pm
# 2      Logística y Distribución   Guayaquil  16/08/2020 - 12:46:36 pm
# 3  Mantenimiento y Reparaciones  Portoviejo  16/08/2020 - 12:25:27 pm
# 4  Mantenimiento y Reparaciones       Manta  16/08/2020 - 12:25:22 pm
#
#            Jornada                Tipo de contrato
# 0  Tiempo completo  Contrato a Plazo Indeterminado
# 1  Tiempo Completo           Otro tipo de contrato
# 2  Tiempo Completo  Contrato por tiempo indefinido
# 3  Tiempo Completo  Contrato por tiempo indefinido
# 4  Tiempo Completo  Contrato por tiempo indefinido

# %%
df2 = df.drop(columns=['id', 'Nombre de trabajo', 'Subcategoria', 'Activo desde'])

# %%
df2
# Out:
#                  Compania                    Salario  \
# 0    EMPLEOS EN GUAYAQUIL         $ 500,00 (Mensual)
# 1               PARTESCAT  500,00 US$ (Neto mensual)
# 2          Pluproxsa S.A.  406,00 US$ (Neto mensual)
# 3        MULTIMOTOS S. A.  394,00 US$ (Neto mensual)
# 4            CONFIDENCIAL                 A convenir
# ..                    ...                        ...
# 902    Salinas Yacht Club  480,00 US$ (Neto mensual)
# 903       Segumar sci s a                 A convenir
# 904              GRUPO AK                 A convenir
# 905           Henry sport                 A convenir
# 906          CONFIDENCIAL  850,00 US$ (Neto mensual)
#
#                                      Categoria   Localidad          Jornada  \
# 0    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# 1    Almacenamiento / Logística / Distribución       Quito  Tiempo Completo
# 2    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo Completo
# 3    Almacenamiento / Logística / Distribución  Portoviejo  Tiempo Completo
# 4    Almacenamiento / Logística / Distribución       Manta  Tiempo Completo
# ..                                         ...         ...              ...
# 902   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 903   Administración / Contabilidad / Finanzas   Latacunga  Tiempo Completo
# 904   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 905   Administración / Contabilidad / Finanzas       Quito  Tiempo Completo
# 906   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
#
#                    Tipo de contrato
# 0    Contrato a Plazo Indeterminado
# 1             Otro tipo de contrato
# 2    Contrato por tiempo indefinido
# 3    Contrato por tiempo indefinido
# 4    Contrato por tiempo indefinido
# ..                              ...
# 902  Contrato por tiempo indefinido
# 903  Contrato por tiempo indefinido
# 904  Contrato por tiempo indefinido
# 905  Contrato por tiempo indefinido
# 906  Contrato por tiempo indefinido
#
# [907 rows x 6 columns]

# %%
df3 = df2[df2['Salario'] != 'A convenir']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 0 to 906
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Compania          390 non-null    object
#  1   Salario           390 non-null    object
#  2   Categoria         390 non-null    object
#  3   Localidad         390 non-null    object
#  4   Jornada           390 non-null    object
#  5   Tipo de contrato  390 non-null    object
# dtypes: object(6)
# memory usage: 21.3+ KB

# %%
df3
# Out:
#                             Compania                      Salario  \
# 0               EMPLEOS EN GUAYAQUIL           $ 500,00 (Mensual)
# 1                          PARTESCAT    500,00 US$ (Neto mensual)
# 2                     Pluproxsa S.A.    406,00 US$ (Neto mensual)
# 3                   MULTIMOTOS S. A.    394,00 US$ (Neto mensual)
# 6               EMPLEOS EN GUAYAQUIL           $ 500,00 (Mensual)
# ..                               ...                          ...
# 889           AUTECNA PARTS CIA LTDA    400,00 US$ (Neto mensual)
# 893                     CONFIDENCIAL    700,00 US$ (Neto mensual)
# 897  CONSEJO NORUEGO PARA REFUGIADOS  1.000,00 US$ (Neto mensual)
# 902               Salinas Yacht Club    480,00 US$ (Neto mensual)
# 906                     CONFIDENCIAL    850,00 US$ (Neto mensual)
#
#                                      Categoria   Localidad          Jornada  \
# 0    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# 1    Almacenamiento / Logística / Distribución       Quito  Tiempo Completo
# 2    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo Completo
# 3    Almacenamiento / Logística / Distribución  Portoviejo  Tiempo Completo
# 6    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# ..                                         ...         ...              ...
# 889   Administración / Contabilidad / Finanzas       Quito  Tiempo Completo
# 893   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 897   Administración / Contabilidad / Finanzas      Tulcán  Tiempo Completo
# 902   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 906   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
#
#                     Tipo de contrato
# 0     Contrato a Plazo Indeterminado
# 1              Otro tipo de contrato
# 2     Contrato por tiempo indefinido
# 3     Contrato por tiempo indefinido
# 6     Contrato a Plazo Indeterminado
# ..                               ...
# 889   Contrato por tiempo indefinido
# 893   Contrato por tiempo indefinido
# 897  Contrato por tiempo determinado
# 902   Contrato por tiempo indefinido
# 906   Contrato por tiempo indefinido
#
# [390 rows x 6 columns]

# %%
def parseSalario(s):
    s2 = s.replace('$','')
    commaIdx = s2.find(',')
    final = s2[:commaIdx]
    #print(final)
    #return int(final)
    return final

# %%
df3['Salario'] = df3['Salario'].map(parseSalario)
# Out:
# <ipython-input-73-58f97c5d8ccf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salario'] = df3['Salario'].map(parseSalario)

# %%
df3
# Out:
#                             Compania Salario  \
# 0               EMPLEOS EN GUAYAQUIL     500
# 1                          PARTESCAT     500
# 2                     Pluproxsa S.A.     406
# 3                   MULTIMOTOS S. A.     394
# 6               EMPLEOS EN GUAYAQUIL     500
# ..                               ...     ...
# 889           AUTECNA PARTS CIA LTDA     400
# 893                     CONFIDENCIAL     700
# 897  CONSEJO NORUEGO PARA REFUGIADOS   1.000
# 902               Salinas Yacht Club     480
# 906                     CONFIDENCIAL     850
#
#                                      Categoria   Localidad          Jornada  \
# 0    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# 1    Almacenamiento / Logística / Distribución       Quito  Tiempo Completo
# 2    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo Completo
# 3    Almacenamiento / Logística / Distribución  Portoviejo  Tiempo Completo
# 6    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# ..                                         ...         ...              ...
# 889   Administración / Contabilidad / Finanzas       Quito  Tiempo Completo
# 893   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 897   Administración / Contabilidad / Finanzas      Tulcán  Tiempo Completo
# 902   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 906   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
#
#                     Tipo de contrato
# 0     Contrato a Plazo Indeterminado
# 1              Otro tipo de contrato
# 2     Contrato por tiempo indefinido
# 3     Contrato por tiempo indefinido
# 6     Contrato a Plazo Indeterminado
# ..                               ...
# 889   Contrato por tiempo indefinido
# 893   Contrato por tiempo indefinido
# 897  Contrato por tiempo determinado
# 902   Contrato por tiempo indefinido
# 906   Contrato por tiempo indefinido
#
# [390 rows x 6 columns]

# %%
df3['Salario'] = pd.to_numeric(df3['Salario'])
# Out:
# <ipython-input-78-95b856457402>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salario'] = pd.to_numeric(df3['Salario'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 390 entries, 0 to 906
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Compania          390 non-null    object
#  1   Salario           390 non-null    float64
#  2   Categoria         390 non-null    object
#  3   Localidad         390 non-null    object
#  4   Jornada           390 non-null    object
#  5   Tipo de contrato  390 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 21.3+ KB

# %%
df3
# Out:
#                             Compania  Salario  \
# 0               EMPLEOS EN GUAYAQUIL    500.0
# 1                          PARTESCAT    500.0
# 2                     Pluproxsa S.A.    406.0
# 3                   MULTIMOTOS S. A.    394.0
# 6               EMPLEOS EN GUAYAQUIL    500.0
# ..                               ...      ...
# 889           AUTECNA PARTS CIA LTDA    400.0
# 893                     CONFIDENCIAL    700.0
# 897  CONSEJO NORUEGO PARA REFUGIADOS      1.0
# 902               Salinas Yacht Club    480.0
# 906                     CONFIDENCIAL    850.0
#
#                                      Categoria   Localidad          Jornada  \
# 0    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# 1    Almacenamiento / Logística / Distribución       Quito  Tiempo Completo
# 2    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo Completo
# 3    Almacenamiento / Logística / Distribución  Portoviejo  Tiempo Completo
# 6    Almacenamiento / Logística / Distribución   Guayaquil  Tiempo completo
# ..                                         ...         ...              ...
# 889   Administración / Contabilidad / Finanzas       Quito  Tiempo Completo
# 893   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 897   Administración / Contabilidad / Finanzas      Tulcán  Tiempo Completo
# 902   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
# 906   Administración / Contabilidad / Finanzas   Guayaquil  Tiempo Completo
#
#                     Tipo de contrato
# 0     Contrato a Plazo Indeterminado
# 1              Otro tipo de contrato
# 2     Contrato por tiempo indefinido
# 3     Contrato por tiempo indefinido
# 6     Contrato a Plazo Indeterminado
# ..                               ...
# 889   Contrato por tiempo indefinido
# 893   Contrato por tiempo indefinido
# 897  Contrato por tiempo determinado
# 902   Contrato por tiempo indefinido
# 906   Contrato por tiempo indefinido
#
# [390 rows x 6 columns]

# %%
df3['Jornada'] = df3['Jornada'].apply(lambda x: x.upper())
# Out:
# <ipython-input-137-d6c9e34d9943>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Jornada'] = df3['Jornada'].apply(lambda x: x.upper())

# %%
df['Jornada'] = df['Jornada'].apply(lambda x: x.upper())

# %%
df
# Out:
#       id                        Nombre de trabajo              Compania  \
# 0      0     Se necesita personal de 17 a 35 años  EMPLEOS EN GUAYAQUIL
# 1      1                       Auxiliar de bodega             PARTESCAT
# 2      2                         Chofer y oficial        Pluproxsa S.A.
# 3      3                    Mecánico Motocicletas      MULTIMOTOS S. A.
# 4      4                                 Mecánico          CONFIDENCIAL
# ..   ...                                      ...                   ...
# 902  902                  Asistente de directorio    Salinas Yacht Club
# 903  903                      Jefe administrativo       Segumar sci s a
# 904  904                   Gerente de Operaciones              GRUPO AK
# 905  905                       Asistente contable           Henry sport
# 906  906  Coordinación de Marketing y Operaciones          CONFIDENCIAL
#
#                        Salario                                  Categoria  \
# 0           $ 500,00 (Mensual)  Almacenamiento / Logística / Distribución
# 1    500,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 2    406,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 3    394,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 4                   A convenir  Almacenamiento / Logística / Distribución
# ..                         ...                                        ...
# 902  480,00 US$ (Neto mensual)   Administración / Contabilidad / Finanzas
# 903                 A convenir   Administración / Contabilidad / Finanzas
# 904                 A convenir   Administración / Contabilidad / Finanzas
# 905                 A convenir   Administración / Contabilidad / Finanzas
# 906  850,00 US$ (Neto mensual)   Administración / Contabilidad / Finanzas
#
#                      Subcategoria   Localidad              Activo desde  \
# 0           Oficios y Profesiones   Guayaquil  16/08/2020 - 14:32:54 pm
# 1        Logística y Distribución       Quito  16/08/2020 - 12:46:40 pm
# 2        Logística y Distribución   Guayaquil  16/08/2020 - 12:46:36 pm
# 3    Mantenimiento y Reparaciones  Portoviejo  16/08/2020 - 12:25:27 pm
# 4    Mantenimiento y Reparaciones       Manta  16/08/2020 - 12:25:22 pm
# ..                            ...         ...                       ...
# 902                Administración   Guayaquil  28/07/2020 - 10:25:42 am
# 903                Administración   Latacunga  27/07/2020 - 17:15:25 pm
# 904                Administración   Guayaquil  27/07/2020 - 17:15:22 pm
# 905       Contabilidad / Finanzas       Quito  27/07/2020 - 12:01:57 pm
# 906                Administración   Guayaquil  27/07/2020 - 12:01:06 pm
#
#              Jornada                Tipo de contrato
# 0    TIEMPO COMPLETO  Contrato a Plazo Indeterminado
# 1    TIEMPO COMPLETO           Otro tipo de contrato
# 2    TIEMPO COMPLETO  Contrato por tiempo indefinido
# 3    TIEMPO COMPLETO  Contrato por tiempo indefinido
# 4    TIEMPO COMPLETO  Contrato por tiempo indefinido
# ..               ...                             ...
# 902  TIEMPO COMPLETO  Contrato por tiempo indefinido
# 903  TIEMPO COMPLETO  Contrato por tiempo indefinido
# 904  TIEMPO COMPLETO  Contrato por tiempo indefinido
# 905  TIEMPO COMPLETO  Contrato por tiempo indefinido
# 906  TIEMPO COMPLETO  Contrato por tiempo indefinido
#
# [907 rows x 10 columns]

# %%
df3
# Out:
#                             Compania  Salario  \
# 0               EMPLEOS EN GUAYAQUIL    500.0
# 1                          PARTESCAT    500.0
# 2                     Pluproxsa S.A.    406.0
# 3                   MULTIMOTOS S. A.    394.0
# 6               EMPLEOS EN GUAYAQUIL    500.0
# ..                               ...      ...
# 889           AUTECNA PARTS CIA LTDA    400.0
# 893                     CONFIDENCIAL    700.0
# 897  CONSEJO NORUEGO PARA REFUGIADOS      1.0
# 902               Salinas Yacht Club    480.0
# 906                     CONFIDENCIAL    850.0
#
#                                      Categoria   Localidad          Jornada  \
# 0    Almacenamiento / Logística / Distribución   Guayaquil  TIEMPO COMPLETO
# 1    Almacenamiento / Logística / Distribución       Quito  TIEMPO COMPLETO
# 2    Almacenamiento / Logística / Distribución   Guayaquil  TIEMPO COMPLETO
# 3    Almacenamiento / Logística / Distribución  Portoviejo  TIEMPO COMPLETO
# 6    Almacenamiento / Logística / Distribución   Guayaquil  TIEMPO COMPLETO
# ..                                         ...         ...              ...
# 889   Administración / Contabilidad / Finanzas       Quito  TIEMPO COMPLETO
# 893   Administración / Contabilidad / Finanzas   Guayaquil  TIEMPO COMPLETO
# 897   Administración / Contabilidad / Finanzas      Tulcán  TIEMPO COMPLETO
# 902   Administración / Contabilidad / Finanzas   Guayaquil  TIEMPO COMPLETO
# 906   Administración / Contabilidad / Finanzas   Guayaquil  TIEMPO COMPLETO
#
#                     Tipo de contrato
# 0     Contrato a Plazo Indeterminado
# 1              Otro tipo de contrato
# 2     Contrato por tiempo indefinido
# 3     Contrato por tiempo indefinido
# 6     Contrato a Plazo Indeterminado
# ..                               ...
# 889   Contrato por tiempo indefinido
# 893   Contrato por tiempo indefinido
# 897  Contrato por tiempo determinado
# 902   Contrato por tiempo indefinido
# 906   Contrato por tiempo indefinido
#
# [390 rows x 6 columns]

# %%
G = nx.DiGraph()

# %%
for index, row in df.iterrows():    
    G.add_edge(row['Categoria'], row['Jornada'])

# %%
plt.figure(figsize=(20, 30))
nx.spring_layout(G)
nx.draw_networkx(G)

# %%
d = nx.degree(G)

# %%
plt.figure(figsize=(20, 30))
nx.spring_layout(G)
nx.draw_networkx(G, nodelist=list(dict(d).keys()), node_size=[v * v * 100 for v in list(dict(d).values())])

# %%
G2 = nx.DiGraph()
for index, row in df.iterrows():    
    G2.add_edge(row['Localidad'], row['Jornada'])

# %%
d2 = nx.degree(G2)

# %%
plt.figure(figsize=(20, 30))
nx.spring_layout(G2)
nx.draw_networkx(G2, nodelist=list(dict(d2).keys()), node_size=[v * 200 for v in list(dict(d2).values())])
