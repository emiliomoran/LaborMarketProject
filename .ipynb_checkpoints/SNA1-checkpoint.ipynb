# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('analystFinal2.csv')

# %%
df.head()
# Out:
#    id                     Nombre de trabajo              Compania  \
# 0   0  Se necesita personal de 17 a 35 años  EMPLEOS EN GUAYAQUIL
# 1   1                    Auxiliar de bodega             PARTESCAT
# 2   2                      Chofer y oficial        Pluproxsa S.A.
# 3   3                 Mecánico Motocicletas      MULTIMOTOS S. A.
# 4   4                              Mecánico          CONFIDENCIAL
#
#                      Salario                                  Categoria  \
# 0         $ 500,00 (Mensual)  Almacenamiento / Logística / Distribución
# 1  500,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 2  406,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 3  394,00 US$ (Neto mensual)  Almacenamiento / Logística / Distribución
# 4                 A convenir  Almacenamiento / Logística / Distribución
#
#                    Subcategoria   Localidad              Activo desde  \
# 0         Oficios y Profesiones   Guayaquil  16/08/2020 - 14:32:54 pm
# 1      Logística y Distribución       Quito  16/08/2020 - 12:46:40 pm
# 2      Logística y Distribución   Guayaquil  16/08/2020 - 12:46:36 pm
# 3  Mantenimiento y Reparaciones  Portoviejo  16/08/2020 - 12:25:27 pm
# 4  Mantenimiento y Reparaciones       Manta  16/08/2020 - 12:25:22 pm
#
#            Jornada                Tipo de contrato
# 0  Tiempo completo  Contrato a Plazo Indeterminado
# 1  Tiempo Completo           Otro tipo de contrato
# 2  Tiempo Completo  Contrato por tiempo indefinido
# 3  Tiempo Completo  Contrato por tiempo indefinido
# 4  Tiempo Completo  Contrato por tiempo indefinido

# %%
df['Categoria'].unique()
# Out:
# array(['Almacenamiento / Logística / Distribución',
#        'Comercial / Ventas / Atención al Cliente',
#        'Diseño / Decoración / Artes Gráficas',
#        'Recursos Humanos / Relaciones Públicas',
#        'Informática / Telecomunicaciones', 'Medicina / Salud',
#        'Producción / Mantenimiento / Operaciones',
#        'Marketing / Publicidad / Producción Audiovisual',
#        'Legal / Asesoría', 'Arquitectura / Ingenierías',
#        'Hotelería / Turismo', 'Docencia / Educación',
#        'Compras / Comercio Exterior',
#        'Construcción / Obras / Edificaciones',
#        'Administración / Contabilidad / Finanzas'], dtype=object)

# %%
df['Jornada'].unique()
# Out:
# array(['Tiempo completo', 'Tiempo Completo', 'Medio Tiempo', 'Por Horas',
#        'Desde casa', 'Desde Casa', 'Beca/Prácticas', 'Tiempo parcial',
#        'Por horas'], dtype=object)

# %%
dfSNA1 = df[['Categoria', 'Jornada']]

# %%
dfSNA1.head()
# Out:
#                                    Categoria          Jornada
# 0  Almacenamiento / Logística / Distribución  Tiempo completo
# 1  Almacenamiento / Logística / Distribución  Tiempo Completo
# 2  Almacenamiento / Logística / Distribución  Tiempo Completo
# 3  Almacenamiento / Logística / Distribución  Tiempo Completo
# 4  Almacenamiento / Logística / Distribución  Tiempo Completo

# %%
dfSNA1['Categoria'] = dfSNA1['Categoria'].apply(lambda x: x.upper())
dfSNA1['Jornada'] = dfSNA1['Jornada'].apply(lambda x: x.upper())
# Out:
# <ipython-input-8-be1567fb15ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSNA1['Categoria'] = dfSNA1['Categoria'].apply(lambda x: x.upper())
# <ipython-input-8-be1567fb15ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSNA1['Jornada'] = dfSNA1['Jornada'].apply(lambda x: x.upper())

# %%
dfSNA1.head()
# Out:
#                                    Categoria          Jornada
# 0  ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN  TIEMPO COMPLETO
# 1  ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN  TIEMPO COMPLETO
# 2  ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN  TIEMPO COMPLETO
# 3  ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN  TIEMPO COMPLETO
# 4  ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN  TIEMPO COMPLETO

# %%
G = nx.DiGraph()
for index, row in dfSNA1.iterrows():    
    G.add_edge(row['Categoria'], row['Jornada'])
    G[row['Categoria']][row['Jornada']]['weight'] = G[row['Categoria']][row['Jornada']].get('weight', 0) + 1

# %%
plt.figure(figsize=(20, 20))
nx.spring_layout(G)
nx.draw_networkx(G)

# %%
nx.to_dict_of_dicts(G)
# Out:
# {'ALMACENAMIENTO / LOGÍSTICA / DISTRIBUCIÓN': {'TIEMPO COMPLETO': {'weight': 112},
#   'MEDIO TIEMPO': {'weight': 6},
#   'POR HORAS': {'weight': 2}},
#  'TIEMPO COMPLETO': {},
#  'MEDIO TIEMPO': {},
#  'POR HORAS': {},
#  'COMERCIAL / VENTAS / ATENCIÓN AL CLIENTE': {'TIEMPO COMPLETO': {'weight': 151},
#   'MEDIO TIEMPO': {'weight': 27},
#   'DESDE CASA': {'weight': 13},
#   'POR HORAS': {'weight': 9}},
#  'DESDE CASA': {},
#  'DISEÑO / DECORACIÓN / ARTES GRÁFICAS': {'TIEMPO COMPLETO': {'weight': 17},
#   'DESDE CASA': {'weight': 1},
#   'POR HORAS': {'weight': 3},
#   'BECA/PRÁCTICAS': {'weight': 3},
#   'MEDIO TIEMPO': {'weight': 2}},
#  'BECA/PRÁCTICAS': {},
#  'RECURSOS HUMANOS / RELACIONES PÚBLICAS': {'POR HORAS': {'weight': 1},
#   'DESDE CASA': {'weight': 4},
#   'TIEMPO COMPLETO': {'weight': 26}},
#  'INFORMÁTICA / TELECOMUNICACIONES': {'MEDIO TIEMPO': {'weight': 2},
#   'TIEMPO COMPLETO': {'weight': 61},
#   'POR HORAS': {'weight': 9},
#   'DESDE CASA': {'weight': 7},
#   'BECA/PRÁCTICAS': {'weight': 1}},
#  'MEDICINA / SALUD': {'TIEMPO COMPLETO': {'weight': 68},
#   'POR HORAS': {'weight': 11},
#   'MEDIO TIEMPO': {'weight': 4}},
#  'PRODUCCIÓN / MANTENIMIENTO / OPERACIONES': {'TIEMPO COMPLETO': {'weight': 31},
#   'TIEMPO PARCIAL': {'weight': 1},
#   'POR HORAS': {'weight': 4}},
#  'TIEMPO PARCIAL': {},
#  'MARKETING / PUBLICIDAD / PRODUCCIÓN AUDIOVISUAL': {'TIEMPO COMPLETO': {'weight': 47},
#   'POR HORAS': {'weight': 6},
#   'DESDE CASA': {'weight': 22},
#   'BECA/PRÁCTICAS': {'weight': 1},
#   'MEDIO TIEMPO': {'weight': 4}},
#  'LEGAL / ASESORÍA': {'POR HORAS': {'weight': 3},
#   'DESDE CASA': {'weight': 3},
#   'TIEMPO COMPLETO': {'weight': 8},
#   'MEDIO TIEMPO': {'weight': 1}},
#  'ARQUITECTURA / INGENIERÍAS': {'TIEMPO COMPLETO': {'weight': 23},
#   'DESDE CASA': {'weight': 2},
#   'POR HORAS': {'weight': 2}},
#  'HOTELERÍA / TURISMO': {'TIEMPO COMPLETO': {'weight': 20},
#   'POR HORAS': {'weight': 4},
#   'MEDIO TIEMPO': {'weight': 3}},
#  'DOCENCIA / EDUCACIÓN': {'DESDE CASA': {'weight': 1},
#   'POR HORAS': {'weight': 14},
#   'MEDIO TIEMPO': {'weight': 3},
#   'TIEMPO COMPLETO': {'weight': 4}},
#  'COMPRAS / COMERCIO EXTERIOR': {'MEDIO TIEMPO': {'weight': 1},
#   'TIEMPO COMPLETO': {'weight': 14},
#   'DESDE CASA': {'weight': 1},
#   'BECA/PRÁCTICAS': {'weight': 1}},
#  'CONSTRUCCIÓN / OBRAS / EDIFICACIONES': {'TIEMPO COMPLETO': {'weight': 18},
#   'POR HORAS': {'weight': 4},
#   'MEDIO TIEMPO': {'weight': 1}},
#  'ADMINISTRACIÓN / CONTABILIDAD / FINANZAS': {'TIEMPO COMPLETO': {'weight': 108},
#   'MEDIO TIEMPO': {'weight': 2},
#   'DESDE CASA': {'weight': 6},
#   'BECA/PRÁCTICAS': {'weight': 4}}}

# %%
# plt.figure(figsize=(60, 20))
dfSNA1.groupby('Jornada').Categoria.value_counts().unstack(0).plot(kind='bar', figsize=(15, 5))
plt.show()
